# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("preprocessed_house_rent.csv")

# %%
dataset
# Out:
#       BHK   Rent  Size  Area Type  Furnishing Status  Tenant Preferred  \
# 0       2  10000  1100          2                  2                 1
# 1       2  20000   800          2                  1                 1
# 2       2  17000  1000          2                  1                 1
# 3       2  10000   800          2                  2                 1
# 4       2   7500   850          1                  2                 0
# ...   ...    ...   ...        ...                ...               ...
# 4741    2  15000  1000          1                  1                 1
# 4742    3  29000  2000          2                  1                 1
# 4743    3  35000  1750          1                  1                 1
# 4744    3  45000  1500          1                  1                 2
# 4745    2  15000  1000          1                  2                 0
#
#       Bathroom  City_Chennai  City_Delhi  City_Hyderabad  City_Kolkata  \
# ...

# %%
print(dataset.isnull().sum())
# Out:
# BHK                  0
# Rent                 0
# Size                 0
# Area Type            0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# City_Chennai         0
# City_Delhi           0
# City_Hyderabad       0
# City_Kolkata         0
# City_Mumbai          0
# Floor Number         0
# Total Floors         0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['BHK', 'Rent', 'Size', 'Area Type', 'Furnishing Status',
#        'Tenant Preferred', 'Bathroom', 'City_Chennai', 'City_Delhi',
#        'City_Hyderabad', 'City_Kolkata', 'City_Mumbai', 'Floor Number',
#        'Total Floors'],
#       dtype='object')

# %%
independent=dataset[[ 'BHK','Size', 'Area Type', 'Furnishing Status',
       'Tenant Preferred', 'Bathroom', 'City_Chennai', 'City_Delhi',
       'City_Hyderabad', 'City_Kolkata', 'City_Mumbai', 'Floor Number',
       'Total Floors']]

# %%
independent
# Out:
#       BHK  Size  Area Type  Furnishing Status  Tenant Preferred  Bathroom  \
# 0       2  1100          2                  2                 1         2
# 1       2   800          2                  1                 1         1
# 2       2  1000          2                  1                 1         1
# 3       2   800          2                  2                 1         1
# 4       2   850          1                  2                 0         1
# ...   ...   ...        ...                ...               ...       ...
# 4741    2  1000          1                  1                 1         2
# 4742    3  2000          2                  1                 1         3
# 4743    3  1750          1                  1                 1         3
# 4744    3  1500          1                  1                 2         2
# 4745    2  1000          1                  2                 0         2
#
#       City_Chennai  City_Delhi  City_Hyderabad  City_Kolkata  City_Mumbai  \
# ...

# %%
dependent=dataset[['Rent']]

# %%
dependent
# Out:
#        Rent
# 0     10000
# 1     20000
# 2     17000
# 3     10000
# 4      7500
# ...     ...
# 4741  15000
# 4742  29000
# 4743  35000
# 4744  45000
# 4745  15000
#
# [4746 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
independent=sc.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':["squared_error","absolute_error","friedman_mse","poisson"],
'max_features': ["sqrt","log2",None],
'splitter':["best","random"]}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,cv=5,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'random'}: 0.9624831101933243

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.018993      0.006134         0.005429        0.006776
# 1        0.013622      0.003476         0.005065        0.004148
# 2        0.022040      0.004413         0.006315        0.003162
# 3        0.013045      0.004043         0.003238        0.003966
# 4        0.031290      0.011277         0.008933        0.005813
# 5        0.021081      0.002867         0.006834        0.001725
# 6        0.296881      0.024318         0.000000        0.000000
# 7        0.279777      0.046342         0.000000        0.000000
# 8        0.316171      0.025478         0.003125        0.006250
# 9        0.269947      0.033774         0.000000        0.000000
# 10       0.893217      0.063776         0.003125        0.006250
# 11       0.762345      0.115069         0.000000        0.000000
# 12       0.020957      0.006856         0.000000        0.000000
# ...

# %%
import pickle
filename="finalized_model_Decisiontree.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
BHK_input=float(input("BHK:"))
Size_input=float(input("Size:"))
Area_Type_input=float(input("Area Type:"))
Furnishing_Status_input = float(input("Furnishing Status:"))
Tenant_Preferred_input=float(input("Tenant Preferred:"))
Bathroom_input=float(input("Bathroom:"))
City_Chennai_input=float(input("City_Chennai:")) 
City_Delhi_input=float(input("City_Delhi:"))     
City_Hyderabad_input=float(input("City_Hyderabad:"))
City_Kolkata_input=float(input("City_Kolkata:")) 
City_Mumbai_input=float(input("City_Mumbai:"))
Floor_Number_input=float(input("Floor_Number':"))
Total_Floors_input=float(input("Total_Floors:"))
# Out:
# BHK: 2
# Size: 1100
# Area Type: 1
# Furnishing Status: 1
# Tenant Preferred: 1
# Bathroom: 2
# City_Chennai: 1
# City_Delhi: 1
# City_Hyderabad: 0
# City_Kolkata: 1
# City_Mumbai: 0
# Floor_Number': 1
# Total_Floors: 2

# %%
loaded_model=pickle.load(open("finalized_model_Decisiontree.sav",'rb'))

# %%
Preinput = sc.fit_transform([[BHK_input, Size_input, Area_Type_input,Furnishing_Status_input,Tenant_Preferred_input,Bathroom_input,City_Chennai_input,City_Delhi_input,City_Hyderabad_input,City_Kolkata_input,City_Mumbai_input,Floor_Number_input,Total_Floors_input]])

# %%
Future_Prediction=grid.predict(Preinput)

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[13500.]
