# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("preprocessed_house_rent.csv")

# %%
dataset
# Out:
#       BHK   Rent  Size  City  Bathroom  Area Type_Carpet Area  \
# 0       2  10000  1100     4         2                      0
# 1       2  20000   800     4         1                      0
# 2       2  17000  1000     4         1                      0
# 3       2  10000   800     4         1                      0
# 4       2   7500   850     4         1                      1
# ...   ...    ...   ...   ...       ...                    ...
# 4741    2  15000  1000     3         2                      1
# 4742    3  29000  2000     3         3                      0
# 4743    3  35000  1750     3         3                      1
# 4744    3  45000  1500     3         2                      1
# 4745    2  15000  1000     3         2                      1
#
#       Area Type_Super Area  Tenant Preferred_Bachelors/Family  \
# 0                        1                                  1
# 1                        1                                  1
# 2                        1                                  1
# 3                        1                                  1
# 4                        0                                  0
# ...                    ...                                ...
# 4741                     0                                  1
# 4742                     1                                  1
# 4743                     0                                  1
# 4744                     0                                  0
# 4745                     0                                  0
#
#       Tenant Preferred_Family  Furnishing Status_Semi-Furnished  \
# 0                           0                                 0
# 1                           0                                 1
# 2                           0                                 1
# 3                           0                                 0
# 4                           0                                 0
# ...                       ...                               ...
# 4741                        0                                 1
# 4742                        0                                 1
# 4743                        0                                 1
# 4744                        1                                 1
# 4745                        0                                 0
#
#       Furnishing Status_Unfurnished  Floor Number  Total Floors
# 0                                 1             0             2
# 1                                 0             1             3
# 2                                 0             1             3
# 3                                 1             1             2
# 4                                 1             1             2
# ...                             ...           ...           ...
# 4741                              0             3             5
# 4742                              0             1             4
# 4743                              0             3             5
# 4744                              0            23            34
# 4745                              1             4             5
#
# [4746 rows x 13 columns]

# %%
print(dataset.isnull().sum())
# Out:
# BHK                                  0
# Rent                                 0
# Size                                 0
# City                                 0
# Bathroom                             0
# Area Type_Carpet Area                0
# Area Type_Super Area                 0
# Tenant Preferred_Bachelors/Family    0
# Tenant Preferred_Family              0
# Furnishing Status_Semi-Furnished     0
# Furnishing Status_Unfurnished        0
# Floor Number                         0
# Total Floors                         0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['BHK', 'Rent', 'Size', 'City', 'Bathroom', 'Area Type_Carpet Area',
#        'Area Type_Super Area', 'Tenant Preferred_Bachelors/Family',
#        'Tenant Preferred_Family', 'Furnishing Status_Semi-Furnished',
#        'Furnishing Status_Unfurnished', 'Floor Number', 'Total Floors'],
#       dtype='object')

# %%
independent=dataset[[ 'BHK', 'Size','Area Type_Carpet Area','Area Type_Super Area','Tenant Preferred_Bachelors/Family',
       'Tenant Preferred_Family', 'Furnishing Status_Semi-Furnished','Furnishing Status_Unfurnished', 
       'Bathroom', 'City', 'Floor Number','Total Floors']]

# %%
independent
# Out:
#       BHK  Size  Area Type_Carpet Area  Area Type_Super Area  \
# 0       2  1100                      0                     1
# 1       2   800                      0                     1
# 2       2  1000                      0                     1
# 3       2   800                      0                     1
# 4       2   850                      1                     0
# ...   ...   ...                    ...                   ...
# 4741    2  1000                      1                     0
# 4742    3  2000                      0                     1
# 4743    3  1750                      1                     0
# 4744    3  1500                      1                     0
# 4745    2  1000                      1                     0
#
#       Tenant Preferred_Bachelors/Family  Tenant Preferred_Family  \
# 0                                     1                        0
# 1                                     1                        0
# 2                                     1                        0
# 3                                     1                        0
# 4                                     0                        0
# ...                                 ...                      ...
# 4741                                  1                        0
# 4742                                  1                        0
# 4743                                  1                        0
# 4744                                  0                        1
# 4745                                  0                        0
#
#       Furnishing Status_Semi-Furnished  Furnishing Status_Unfurnished  \
# 0                                    0                              1
# 1                                    1                              0
# 2                                    1                              0
# 3                                    0                              1
# 4                                    0                              1
# ...                                ...                            ...
# 4741                                 1                              0
# 4742                                 1                              0
# 4743                                 1                              0
# 4744                                 1                              0
# 4745                                 0                              1
#
#       Bathroom  City  Floor Number  Total Floors
# 0            2     4             0             2
# 1            1     4             1             3
# 2            1     4             1             3
# 3            1     4             1             2
# 4            1     4             1             2
# ...        ...   ...           ...           ...
# 4741         2     3             3             5
# 4742         3     3             1             4
# 4743         3     3             3             5
# 4744         2     3            23            34
# 4745         2     3             4             5
#
# [4746 rows x 12 columns]

# %%
dependent=dataset[['Rent']]

# %%
dependent
# Out:
#        Rent
# 0     10000
# 1     20000
# 2     17000
# 3     10000
# 4      7500
# ...     ...
# 4741  15000
# 4742  29000
# 4743  35000
# 4744  45000
# 4745  15000
#
# [4746 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
independent=sc.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':["squared_error","absolute_error","friedman_mse","poisson"],
'max_features': ["sqrt","log2",None],
'splitter':["best","random"]}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,cv=5,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'}: 0.9998240387328334

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.025080  7.557877e-03         0.003125        0.006250
# 1        0.019853  1.001335e-02         0.003127        0.006253
# 2        0.016689  3.231715e-03         0.003126        0.006252
# 3        0.015627  2.226375e-06         0.003125        0.006250
# 4        0.040788  1.003016e-02         0.004227        0.006085
# 5        0.018749  6.253576e-03         0.009375        0.007655
# 6        0.282497  3.277489e-02         0.000000        0.000000
# 7        0.217012  2.505625e-02         0.002535        0.003754
# 8        0.328238  4.238800e-02         0.006250        0.007655
# 9        0.259225  4.065218e-02         0.003102        0.006204
# 10       0.898479  8.128309e-02         0.000000        0.000000
# 11       0.671144  1.171425e-01         0.003125        0.006250
# 12       0.011578  6.058890e-03         0.006249        0.007653
# 13       0.012500  6.250215e-03         0.003125        0.006250
# 14       0.015789  6.842356e-03         0.006333        0.006171
# 15       0.018755  6.251526e-03         0.000000        0.000000
# 16       0.028125  6.249762e-03         0.003125        0.006249
# 17       0.015624  4.768372e-07         0.003125        0.006249
# 18       0.018994  6.958774e-03         0.002902        0.005805
# 19       0.015180  5.459815e-04         0.003127        0.006254
# 20       0.021876  7.658588e-03         0.003125        0.006250
# 21       0.017128  3.008771e-03         0.006250        0.007654
# 22       0.034702  6.292594e-03         0.000000        0.000000
# 23       0.021957  7.756285e-03         0.003125        0.006249
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6   absolute_error               sqrt           best
# 7   absolute_error               sqrt         random
# 8   absolute_error               log2           best
# 9   absolute_error               log2         random
# 10  absolute_error               None           best
# 11  absolute_error               None         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
# 16    friedman_mse               None           best
# 17    friedman_mse               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...          -0.156377
# 1   {'criterion': 'squared_error', 'max_features':...           0.305556
# 2   {'criterion': 'squared_error', 'max_features':...          -1.751188
# 3   {'criterion': 'squared_error', 'max_features':...           0.517484
# 4   {'criterion': 'squared_error', 'max_features':...          -1.470243
# 5   {'criterion': 'squared_error', 'max_features':...           0.451391
# 6   {'criterion': 'absolute_error', 'max_features'...           0.486645
# 7   {'criterion': 'absolute_error', 'max_features'...           0.527551
# 8   {'criterion': 'absolute_error', 'max_features'...           0.400715
# 9   {'criterion': 'absolute_error', 'max_features'...           0.326734
# 10  {'criterion': 'absolute_error', 'max_features'...           0.594956
# 11  {'criterion': 'absolute_error', 'max_features'...           0.024549
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.493401
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.440792
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.337166
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.612011
# 16  {'criterion': 'friedman_mse', 'max_features': ...          -1.468844
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.479752
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.268195
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...          -0.032619
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.572622
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.342841
# 22  {'criterion': 'poisson', 'max_features': None,...           0.669517
# 23  {'criterion': 'poisson', 'max_features': None,...           0.239513
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.075084         -28.912706           0.066104
# 1            0.168041           0.204420          -7.716075
# 2            0.220635           0.246677           0.010082
# 3            0.124278         -38.985201           0.031167
# 4            0.214422          -9.330933          -0.149875
# 5            0.234806         -27.968471          -0.085319
# 6            0.081803          -9.656082          -0.040448
# 7            0.180154          -9.991358           0.276578
# 8            0.155059         -17.359006           0.044877
# 9            0.202726           0.361864          -0.399446
# 10           0.269575         -18.034496           0.242560
# 11           0.182088         -18.584524           0.145170
# 12           0.237168         -19.182978          -9.011397
# 13           0.106398          -0.076378           0.188404
# 14           0.249030           0.168049          -8.960514
# 15           0.140156           0.378966           0.187328
# 16           0.224514          -9.379873          -0.161865
# 17           0.275543         -18.523665           0.121500
# 18           0.161020           0.422221          -0.096497
# 19           0.183040         -18.845823          -8.758165
# 20           0.174742          -8.773155          -0.156333
# 21           0.203566          -9.760588           0.182516
# 22           0.239082         -38.075999           0.005622
# 23           0.255986          -9.870545           0.122744
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -1.442049        -6.073989       11.433213               21
# 1           -1.361798        -1.679971        3.080396                6
# 2           -0.934755        -0.441710        0.784158                5
# 3           -7.299950        -9.122445       15.213970               24
# 4           -1.001208        -2.347568        3.542412               11
# 5           -1.630306        -5.799580       11.108410               19
# 6           -1.013081        -2.028233        3.845589                7
# 7           -1.466449        -2.094705        4.010637                9
# 8           -4.072307        -4.166132        6.801796               16
# 9           -1.204668        -0.142558        0.597991                3
# 10          -1.777389        -3.740959        7.196023               14
# 11          -2.135056        -4.073555        7.307922               15
# 12          -0.999569        -5.692675        7.595499               18
# 13          -1.494366        -0.167030        0.684190                4
# 14         -19.334978        -5.508249        7.779872               17
# 15          -0.798866         0.103919        0.481061                1
# 16          -1.051961        -2.367606        3.557948               12
# 17         -21.642198        -7.857813       10.031008               23
# 18          -1.338125        -0.116637        0.633718                2
# 19          -1.937370        -5.878187        7.251111               20
# 20          -3.040323        -2.244489        3.504455               10
# 21          -4.412523        -2.688837        3.969446               13
# 22          -1.738579        -7.780071       15.170117               22
# 23          -1.129947        -2.076450        3.931518                8

# %%
import pickle
filename="finalized_model_Decisiontree.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
BHK_input=float(input("BHK:"))
Size_input=float(input("Size:"))
Area_Type_Carpet_Area_input=float(input("Area Type_Carpet Area:"))
Area_Type_Super_Area_input=float(input("Area Type_Super Area:"))
City_input=float(input("City:"))
Furnishing_Status_Semi_Furnished_input = float(input("Furnishing Status Semi-Furnished: "))
Furnishing_Status_Unfurnished_input=float(input("Furnishing Status_Unfurnished:"))
Tenant_Preferred_Bachelors_Family_input = float(input("Tenant Preferred Bachelors/Family: "))
Tenant_Preferred_Family_input=float(input("Tenant Preferred_Family:"))
Bathroom_input=float(input("Bathroom:"))
Floor_Number_input=float(input("Floor_Number':"))
Total_Floors_input=float(input("Total_Floors:"))
# Out:
# BHK: 2
# Size: 800
# Area Type_Carpet Area: 1
# Area Type_Super Area: 0
# City: 3
# Furnishing Status Semi-Furnished:  1
# Furnishing Status_Unfurnished: 0
# Tenant Preferred Bachelors/Family:  0
# Tenant Preferred_Family: 1
# Bathroom: 1
# Floor_Number': 2
# Total_Floors: 2

# %%
loaded_model=pickle.load(open("finalized_model_Decisiontree.sav",'rb'))

# %%
Preinput = sc.fit_transform([[BHK_input, Size_input, Area_Type_Carpet_Area_input, Area_Type_Super_Area_input, City_input, Furnishing_Status_Semi_Furnished_input, Furnishing_Status_Unfurnished_input, Tenant_Preferred_Bachelors_Family_input, Tenant_Preferred_Family_input, Bathroom_input, Floor_Number_input, Total_Floors_input]])

# %%
Future_Prediction=grid.predict(Preinput)

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[13500.]
