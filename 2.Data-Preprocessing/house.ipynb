# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv("House_rent.csv")

# %%
df
# Out:
#       BHK   Rent  Size            Floor    Area Type  \
# 0       2  10000  1100  Ground out of 2   Super Area
# 1       2  20000   800       1 out of 3   Super Area
# 2       2  17000  1000       1 out of 3   Super Area
# 3       2  10000   800       1 out of 2   Super Area
# 4       2   7500   850       1 out of 2  Carpet Area
# ...   ...    ...   ...              ...          ...
# 4741    2  15000  1000       3 out of 5  Carpet Area
# 4742    3  29000  2000       1 out of 4   Super Area
# 4743    3  35000  1750       3 out of 5  Carpet Area
# 4744    3  45000  1500     23 out of 34  Carpet Area
# 4745    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# ...

# %%
# 2. Check for missing values
df.isnull().sum()
# Out:
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# dtype: int64

# %%
# Clean the 'Floor' column (split into 'Current Floor' and 'Total Floors')
def extract_floors(floor_str):
    try:
        if 'Ground' in floor_str:
            return 0, int(floor_str.split('out of')[-1].strip())
        else:
            parts = floor_str.split('out of')
            return int(parts[0].strip()), int(parts[1].strip())
    except:
        return np.nan, np.nan

df[['Current Floor', 'Total Floors']] = df['Floor'].apply(lambda x: pd.Series(extract_floors(str(x))))

# %%
# Drop original floor column
df.drop('Floor', axis=1, inplace=True)

# %%
# Drop unnecessary columns (optional)
df.drop('Area Locality', axis=1, inplace=True)

# %%
# One-hot encode categorical variables
categorical_cols = ['Area Type', 'City', 'Furnishing Status', 'Tenant Preferred']
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=False,dtype=int)

# %%
# Save the cleaned dataset to a new CSV
df_encoded.to_csv('cleaned_house_rent_dataset.csv', index=False)

# %%
print(" Dataset cleaned and saved as 'cleaned_house_rent_dataset.csv'")
# Out:
#  Dataset cleaned and saved as 'cleaned_house_rent_dataset.csv'
