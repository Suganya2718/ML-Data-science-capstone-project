# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("preprocessed_house_rent.csv")

# %%
dataset
# Out:
#       BHK   Rent  Size  Area Type  City  Furnishing Status  Tenant Preferred  \
# 0       2  10000  1100          2     4                  2                 1
# 1       2  20000   800          2     4                  1                 1
# 2       2  17000  1000          2     4                  1                 1
# 3       2  10000   800          2     4                  2                 1
# 4       2   7500   850          1     4                  2                 0
# ...   ...    ...   ...        ...   ...                ...               ...
# 4741    2  15000  1000          1     3                  1                 1
# 4742    3  29000  2000          2     3                  1                 1
# 4743    3  35000  1750          1     3                  1                 1
# 4744    3  45000  1500          1     3                  1                 2
# 4745    2  15000  1000          1     3                  2                 0
#
#       Bathroom  Floor Number  Total Floors
# 0            2             0             2
# 1            1             1             3
# 2            1             1             3
# 3            1             1             2
# 4            1             1             2
# ...        ...           ...           ...
# 4741         2             3             5
# 4742         3             1             4
# 4743         3             3             5
# 4744         2            23            34
# 4745         2             4             5
#
# [4746 rows x 10 columns]

# %%
print(dataset.isnull().sum())
# Out:
# BHK                  0
# Rent                 0
# Size                 0
# Area Type            0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Floor Number         0
# Total Floors         0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['BHK', 'Rent', 'Size', 'Area Type', 'City', 'Furnishing Status',
#        'Tenant Preferred', 'Bathroom', 'Floor Number', 'Total Floors'],
#       dtype='object')

# %%
independent=dataset[[ 'BHK', 'Size', 'Area Type', 'Furnishing Status',
       'Tenant Preferred', 'Bathroom', 'City', 'Floor Number','Total Floors']]

# %%
independent
# Out:
#       BHK  Size  Area Type  Furnishing Status  Tenant Preferred  Bathroom  \
# 0       2  1100          2                  2                 1         2
# 1       2   800          2                  1                 1         1
# 2       2  1000          2                  1                 1         1
# 3       2   800          2                  2                 1         1
# 4       2   850          1                  2                 0         1
# ...   ...   ...        ...                ...               ...       ...
# 4741    2  1000          1                  1                 1         2
# 4742    3  2000          2                  1                 1         3
# 4743    3  1750          1                  1                 1         3
# 4744    3  1500          1                  1                 2         2
# 4745    2  1000          1                  2                 0         2
#
#       City  Floor Number  Total Floors
# 0        4             0             2
# 1        4             1             3
# 2        4             1             3
# 3        4             1             2
# 4        4             1             2
# ...    ...           ...           ...
# 4741     3             3             5
# 4742     3             1             4
# 4743     3             3             5
# 4744     3            23            34
# 4745     3             4             5
#
# [4746 rows x 9 columns]

# %%
dependent=dataset[['Rent']]

# %%
dependent
# Out:
#        Rent
# 0     10000
# 1     20000
# 2     17000
# 3     10000
# 4      7500
# ...     ...
# 4741  15000
# 4742  29000
# 4743  35000
# 4744  45000
# 4745  15000
#
# [4746 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
independent=sc.fit_transform(independent)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'criterion':["squared_error","absolute_error","friedman_mse","poisson"],
'max_features':["sqrt","log2",None],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(),param_grid,refit=True,cv=5,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}: 0.912475124057603

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.145951      0.013432         0.013386        0.015014
# 1        1.161015      0.018863         0.042383        0.006146
# 2        0.128693      0.006374         0.009457        0.007723
# 3        1.136363      0.060249         0.037195        0.008072
# 4        0.207329      0.005175         0.006251        0.007656
# 5        2.007281      0.272188         0.029821        0.003060
# 6        1.799044      0.166601         0.012378        0.006193
# 7       20.832290      1.064999         0.053674        0.007210
# 8        2.436796      0.050982         0.008954        0.007387
# 9       20.716454      0.883427         0.033756        0.007202
# 10       5.033757      0.792942         0.009352        0.007636
# 11      51.853438      1.857514         0.028584        0.005480
# 12       0.183979      0.018329         0.012603        0.011722
# 13       1.708783      0.077482         0.048858        0.003569
# 14       0.189211      0.011592         0.011860        0.006355
# 15       1.777326      0.051295         0.058235        0.018336
# 16       0.322227      0.009907         0.009053        0.007416
# 17       2.907169      0.108990         0.050249        0.006130
# 18       0.223949      0.033682         0.004034        0.005985
# 19       2.332759      0.071167         0.049544        0.003590
# 20       0.251390      0.008616         0.008154        0.007021
# 21       2.297611      0.021891         0.055806        0.006128
# 22       0.384991      0.008408         0.009615        0.005792
# 23       3.799887      0.319405         0.038484        0.007161
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                 100
# 2    squared_error               log2                  10
# 3    squared_error               log2                 100
# 4    squared_error               None                  10
# 5    squared_error               None                 100
# 6   absolute_error               sqrt                  10
# 7   absolute_error               sqrt                 100
# 8   absolute_error               log2                  10
# 9   absolute_error               log2                 100
# 10  absolute_error               None                  10
# 11  absolute_error               None                 100
# 12    friedman_mse               sqrt                  10
# 13    friedman_mse               sqrt                 100
# 14    friedman_mse               log2                  10
# 15    friedman_mse               log2                 100
# 16    friedman_mse               None                  10
# 17    friedman_mse               None                 100
# 18         poisson               sqrt                  10
# 19         poisson               sqrt                 100
# 20         poisson               log2                  10
# 21         poisson               log2                 100
# 22         poisson               None                  10
# 23         poisson               None                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.742505
# 1   {'criterion': 'squared_error', 'max_features':...           0.766954
# 2   {'criterion': 'squared_error', 'max_features':...           0.745448
# 3   {'criterion': 'squared_error', 'max_features':...           0.740399
# 4   {'criterion': 'squared_error', 'max_features':...           0.691232
# 5   {'criterion': 'squared_error', 'max_features':...           0.724107
# 6   {'criterion': 'absolute_error', 'max_features'...           0.769550
# 7   {'criterion': 'absolute_error', 'max_features'...           0.764869
# 8   {'criterion': 'absolute_error', 'max_features'...           0.722792
# 9   {'criterion': 'absolute_error', 'max_features'...           0.779863
# 10  {'criterion': 'absolute_error', 'max_features'...           0.758317
# 11  {'criterion': 'absolute_error', 'max_features'...           0.770275
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.702080
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.754472
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.670851
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.771784
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.702870
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.692832
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.740770
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.777269
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.543427
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.762129
# 22  {'criterion': 'poisson', 'max_features': None,...           0.648334
# 23  {'criterion': 'poisson', 'max_features': None,...           0.743094
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.288880          -1.130560           0.198574
# 1            0.280748          -1.931807           0.322988
# 2            0.266918          -3.026374           0.383486
# 3            0.284317          -1.058031           0.330544
# 4            0.295918          -6.123555           0.167355
# 5            0.291846          -3.719645          -0.122118
# 6            0.257701          -4.282130           0.346560
# 7            0.284447          -0.684968           0.398693
# 8            0.280347          -1.705326          -0.293562
# 9            0.287895          -0.700619           0.435385
# 10           0.297886          -2.736608           0.153125
# 11           0.297439          -1.830385           0.275957
# 12           0.280882          -1.448355           0.390704
# 13           0.284400          -1.988350           0.336905
# 14           0.269482          -8.466237           0.343639
# 15           0.284538          -1.428946           0.327029
# 16           0.278244          -1.353125          -0.588411
# 17           0.285493          -3.935095           0.230702
# 18           0.277053           0.193239           0.311067
# 19           0.281644          -1.023258           0.384031
# 20           0.277413          -0.678239           0.279695
# 21           0.287096          -2.556355           0.384468
# 22           0.296687          -4.002946          -0.328877
# 23           0.292239          -5.820187           0.194046
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.156535        -0.011427        0.628683                7
# 1           -0.114344        -0.135092        0.940751               11
# 2           -0.323738        -0.390852        1.361904               15
# 3           -0.264023         0.006641        0.620839                6
# 4           -0.387659        -1.071342        2.549616               23
# 5           -0.337762        -0.632715        1.585725               19
# 6           -1.134168        -0.808498        1.851127               20
# 7           -0.181201         0.116368        0.501836                1
# 8           -1.294697        -0.458089        0.918950               17
# 9           -0.236942         0.113116        0.522238                2
# 10          -0.282534        -0.361963        1.232963               14
# 11          -0.175151        -0.132373        0.900147               10
# 12          -0.482780        -0.111494        0.773707                9
# 13          -0.175659        -0.157646        0.961639               12
# 14          -0.044647        -1.445383        3.517791               24
# 15          -0.196245        -0.048368        0.755283                8
# 16          -1.262778        -0.444640        0.819110               16
# 17          -0.362812        -0.617776        1.692520               18
# 18          -1.099663         0.084493        0.621798                3
# 19          -0.194401         0.045057        0.617357                4
# 20          -0.283991         0.027661        0.444372                5
# 21          -0.149833        -0.254499        1.186982               13
# 22          -0.820509        -0.841462        1.659701               21
# 23          -0.203072        -0.958776        2.449278               22

# %%
import pickle
filename="finalized_model_RandomForest.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
dataset.columns
# Out:
# Index(['BHK', 'Rent', 'Size', 'Area Type', 'City', 'Furnishing Status',
#        'Tenant Preferred', 'Bathroom', 'Floor Number', 'Total Floors'],
#       dtype='object')

# %%
BHK_input=float(input("BHK:"))
Size_input=float(input("Size:"))
Area_Type_input=float(input("Area_Type':"))
City_input=float(input("City:"))
Furnishing_Status_input=float(input("Furnishing_Status':"))
Tenant_Preferred_input=float(input("Tenant_Preferred:"))
Bathroom_input=float(input("Bathroom:"))
Floor_Number_input=float(input("Floor_Number':"))
Total_Floors_input=float(input("Total_Floors:"))
# Out:
# BHK: 2
# Size: 1100
# Area_Type': 2
# City: 4
# Furnishing_Status': 1
# Tenant_Preferred: 2
# Bathroom: 2
# Floor_Number': 1
# Total_Floors: 2

# %%
loaded_model=pickle.load(open("finalized_model_RandomForest.sav",'rb'))

# %%
Preinput = sc.fit_transform([[BHK_input,Size_input,Area_Type_input,City_input,Furnishing_Status_input,Tenant_Preferred_input,Bathroom_input,Floor_Number_input,Total_Floors_input]])

# %%
Future_Prediction=grid.predict(Preinput)

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[17776.81]
